# %% [markdown]
# Files
#   ↓
# git add
#   ↓
# Staging
#   ↓
# git commit
#   ↓
# Local Git

# %% [markdown]
# GitHub is an online platform where you can host Git repositories and collaborate with other developers.

# %% [markdown]
# Git
# = version control on your computer
#
# GitHub
# = online place for your repository + collaboration

# %% [markdown]
# YOUR COMPUTER
#
# week4-git-workflow
#         │
#         │
#         │ Git
#         │
#         ↓
# GITHUB
#
# week4-git-workflow

# %% [markdown]
# Local Repository
# = repository روی کامپیوتر
#
# Remote Repository
# = repository روی GitHub

# %% [markdown]
#                  YOUR COMPUTER
#
#                     project
#                        ↓
#                   edit files
#                        ↓
#                   git status
#                        ↓
#                     git add
#                        ↓
#                    git commit
#                        ↓
#                  LOCAL REPO
#                        ↓
#                    git push
#                        ↓
#                   GITHUB REPO

# %% [markdown]
# | Command      | Meaning                                   |
# | ------------ | ----------------------------------------- |
# | `git add`    | Put changes into staging                  |
# | `git commit` | Save a snapshot locally                   |
# | `git push`   | Send local commits to GitHub              |
# | `git pull`   | Get remote changes                        |
# | `git clone`  | Copy a remote repository to your computer |

# %% [markdown]
# Repository name:
# week4-git-workflow
#
# Public/Private:
# Your choice
#
# README:
# ❌ Don't add
#
# .gitignore:
# ❌ Don't add
#
# License:
# ❌ Don't add

# %% [markdown]
#                  YOUR COMPUTER
#
#                     project
#                        ↓
#                   edit files
#                        ↓
#                   git status
#                        ↓
#                     git add
#                        ↓
#                    git commit
#                        ↓
#                  LOCAL REPO
#                        ↓
#                    git push
#                        ↓
#                   GITHUB REPO
