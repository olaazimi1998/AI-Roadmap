# %% [markdown]
# ### EDIT FILE
#    ↓
# git status
#    ↓
# git add
#    ↓
# STAGING AREA
#    ↓
# git commit
#    ↓
# LOCAL GIT HISTORY

# %% [markdown]
# Working Directory
#        ↓
#    git add
#        ↓
# Staging Area
#        ↓
#   git commit
#        ↓
# Git Repository

# %% [markdown]
# ### git
# فایل‌های پروژه
#       ↓
#     git add
#       ↓
# Staging Area
#       ↓
#   git commit
#       ↓
# تاریخچه Git

# %% [markdown]
# git init

# %% [markdown]
# git status

# %% [markdown]
# git add

# %% [markdown]
# git commit -m

# %% [markdown]
# git log --oneline

# %% [markdown]
# git init
#      ↓
# git status
#      ↓
# git add
#      ↓
# git commit
#      ↓
# git log
