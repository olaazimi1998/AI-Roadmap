# %% [markdown]
# Now we use the XOR problem.
#
# Our data:
#
# 0 XOR 0 = 0
# 0 XOR 1 = 1
# 1 XOR 0 = 1
# 1 XOR 1 = 0

# %%
import numpy as np

X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([
    [0],
    [1],
    [1],
    [0]
])

# %% [markdown]
#               ┌──────────────┐
#               │    Input     │
#               └──────┬───────┘
#                      ↓
#               ┌──────────────┐
#               │ Forward Pass │
#               └──────┬───────┘
#                      ↓
#               ┌──────────────┐
#               │  Prediction  │
#               └──────┬───────┘
#                      ↓
#               ┌──────────────┐
#               │     Loss     │
#               └──────┬───────┘
#                      ↓
#               ┌──────────────┐
#               │Backpropagation│
#               └──────┬───────┘
#                      ↓
#               ┌──────────────┐
#               │Update Weights│
#               └──────┬───────┘
#                      ↓
#                    Repeat
