# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
df = pd.read_csv("C:\\Users\\olaaz\\Documents\\AI Roadmap\\First-project\\day1\\products.csv")

# %%
df.head(5)
# Out:
#                  name    brand  buy_price  sell_price  stock  profit
# 0       iphone 15 pro    Apple        800         999      5     995
# 1       iphone 16 pro    Apple        900        1099      6    1194
# 2       iphone 14 pro    Apple        700         899      3     597
# 3  Samsung Galaxy S24  Samsung        650         799      8    1192
# 4  Samsung Galaxy A15  Samsung        400         549     12    1788

# %%
sns.barplot(
    x="name",
    y="sell_price",
    hue="brand",
    data=df
)
plt.xticks(rotation=45, ha="right")
plt.title("Sell Price by Brand")
plt.tight_layout()
plt.show()

# %%
sns.barplot(
    x="name",
    y="buy_price",
    hue="brand",
    data=df
)
plt.xticks(rotation=45, ha="right")
plt.title("buy price by Brand")
plt.tight_layout()
plt.show()

# %%
sns.barplot(
    x="name",
    y="profit",
    hue="brand",
    data=df
)
sns.scatterplot(
    x="name",
    y="profit",
    hue="brand",
    data=df
)
plt.legend(loc="upper right")
plt.xticks(rotation=45, ha="right")
plt.title("profit by Brand")
plt.tight_layout()
plt.show()

# %%
sns.barplot(
    x="name",
    y="profit",
    hue="brand",
    data=df
)
sns.scatterplot(
    x="name",
    y="profit",
    hue="brand",
    data=df
)
sns.set(style="darkgrid")
plt.legend(loc="upper right")
plt.xticks(rotation=45, ha="right")
plt.title("profit by Brand")
plt.tight_layout()
plt.show()
